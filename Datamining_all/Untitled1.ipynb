# %%
import pandas as pd
import math

# load the buys_computer dataset
df = pd.read_csv("/content/sample_data/buys_computer.csv")

# function to calculate entropy
def entropy(data):
    # count the number of instances for each class
    count = data['Class'].value_counts()
    # calculate the probability of each class
    p = count / len(data)
    # calculate entropy
    entropy = -sum(p * np.log2(p))
    return entropy

# function to calculate information gain
def info_gain(data, attribute):
    # calculate the entropy of the whole dataset
    total_entropy = entropy(data)
    # calculate the unique values and their counts for the attribute
    values = data[attribute].value_counts()
    # calculate the weighted entropy of the attribute
    weighted_entropy = 0
    for value, count in values.items():
        subset = data[data[attribute] == value]
        weighted_entropy += count / len(data) * entropy(subset)
    # calculate the information gain
    info_gain = total_entropy - weighted_entropy
    return info_gain

# function to select the top k attributes with the highest information gain
def select_top_k_attributes(data, k):
    # calculate information gain for each attribute
    info_gains = {}
    for attribute in data.columns[:-1]:
        info_gains[attribute] = info_gain(data, attribute)
    # sort the attributes by information gain
    sorted_attributes = sorted(info_gains.items(), key=lambda x: x[1], reverse=True)
    # select the top k attributes
    top_k_attributes = [attribute for attribute, _ in sorted_attributes[:k]]
    return top_k_attributes

# test the functions with k=2
top_k_attributes = select_top_k_attributes(df, 2)
print(top_k_attributes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
