# %%
import pandas as pd

data = pd.read_csv('/content/page_block.csv')


X = data.drop('Class', axis=1)
y = data['Class']

# Assign a rank to each feature based on its Fisher's score.
ranks = f_scores.rank(ascending=False)
# Select the top k ranked features.
# k = 5
# top_features = X[ranks <= k]

print(ranks)

# %%
# Compute Fisher's score for each feature using the formula f=(μ_1^2-μ_2^2)/(σ_1^2+σ_2^2).
f_scores = ((mean_pos - mean_neg)**2) / (std_pos**2 + std_neg**2)

print(f_scores)

# %%
# Compute the standard deviation of each feature against both class labels.
std_neg = X[y == 0].std()
std_pos = X[y == 1].std()

print(std_pos)
# Out:
# Height     NaN
# Lenght     NaN
# Area       NaN
# Eccen      NaN
# P_black    NaN
# P_and      NaN
# Mean_tr    NaN
# Blackpix   NaN
# Blackand   NaN
# Wb_trans   NaN
# dtype: float64

# %%
# Compute the mean of each feature against both class labels.
mean_neg = X[y == 0].mean()
mean_pos = X[y == 1].mean()
print(mean_pos)
# Out:
# Height     NaN
# Lenght     NaN
# Area       NaN
# Eccen      NaN
# P_black    NaN
# P_and      NaN
# Mean_tr    NaN
# Blackpix   NaN
# Blackand   NaN
# Wb_trans   NaN
# dtype: float64
